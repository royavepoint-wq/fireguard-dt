# %% [markdown]
# # 04 - Model Evaluation
# Review confusion matrix and classification report artifacts generated from the unseen test set.

# %%
from pathlib import Path
import pandas as pd

project_root = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
conf = pd.read_csv(project_root / 'data' / 'ml' / 'confusion_matrix.csv', index_col=0)
report = pd.read_csv(project_root / 'data' / 'ml' / 'classification_report.csv', index_col=0)
comparison = pd.read_csv(project_root / 'data' / 'ml' / 'model_comparison.csv')
display(comparison)
display(conf)
display(report)
