# %% [markdown]
# # 03 - Fire Risk Models
# Train Logistic Regression, Random Forest, and Gradient Boosting on the Synthetic Training Dataset.

# %%
from pathlib import Path
import pandas as pd
from app.ml_pipeline.training import build_training_artifacts

project_root = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
artifacts = build_training_artifacts(output_root=project_root)
artifacts

# %%
comparison = pd.read_csv(project_root / 'data' / 'ml' / 'model_comparison.csv')
comparison
