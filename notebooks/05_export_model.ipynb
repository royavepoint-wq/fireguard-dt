# %% [markdown]
# # 05 - Export Model
# Export and inspect the selected Step 5 model artifacts used by FastAPI inference.

# %%
from pathlib import Path
import json

project_root = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
meta_path = project_root / 'backend' / 'models' / 'fire_risk_model_metadata.json'
slide_path = project_root / 'data' / 'ml' / 'slide_metrics.json'
print('Model metadata:', meta_path)
print('Slide metrics:', slide_path)
metadata = json.loads(meta_path.read_text(encoding='utf-8'))
slide = json.loads(slide_path.read_text(encoding='utf-8'))
metadata, slide
